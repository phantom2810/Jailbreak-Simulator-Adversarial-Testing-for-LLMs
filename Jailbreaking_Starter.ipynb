# %%
# Install necessary dependencies for the project
# `fschat`: Likely a library for fine-tuning or interfacing with language models
# `openai`: SDK to interact with OpenAI's API
# !pip install fschat
# !pip install openai==0.28

# %%
# Set the OpenAI API key as an environment variable
# Replace "WRITE_YOUR_OPENAI_KEY" with your actual OpenAI API key

import os
os.environ['OPENAI_API_KEY'] = "WRITE_YOUR_OPENAI_KEY"

# Import the `startKOV` function from the `KOV` module
# This is the main entry point for running the adversarial testing framework
from KOV import startKOV

# %%
# Run the framework with a sample input file and a target model
# Parameters:
# - "sample_input.csv": File containing input prompts or configurations
# - "gpt2": Specifies GPT-2 as the target model for testing

startKOV("sample_input.csv", "gpt2")
